# %%
# Out:
# 1000000000000 1000001000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/xh/jpw0thcs1m75fqy6zj0sfz6c0000gn/T/ipykernel_10969/1916071718.py in <module>
#      45     return cnt
#      46
# ---> 47 print(find_cnt())
#      48
#      49
#
# /var/folders/xh/jpw0thcs1m75fqy6zj0sfz6c0000gn/T/ipykernel_10969/1916071718.py in find_cnt()
#      38         num = i + s
#      39         if (arr[i]) :
# ---> 40             pp = find_divisor(num)
#      41             if pp :
#      42                 erase_sequence(i,pp)
#
# /var/folders/xh/jpw0thcs1m75fqy6zj0sfz6c0000gn/T/ipykernel_10969/1916071718.py in find_divisor(num)
#      26         if pp_num[i] > num : break
#      27
# ---> 28         if num % pp_num[i] == 0 :
#      29             pp = pp_num[i]
#      30             del pp_num[i]
#
# KeyboardInterrupt:

# %%
# Out:
# [25,
#  49,
#  121,
#  169,
#  289,
#  361,
#  529,
#  841,
#  961,
#  1369,
#  1681,
#  1849,
#  2209,
#  2809,
#  3481,
#  3721,
#  4489,
#  5041,
#  5329,
#  6241,
#  6889,
#  7921,
#  9409,
#  10201,
#  10609,
#  11449,
#  11881,
#  12769,
#  16129,
#  17161,
#  18769,
#  19321,
#  22201,
#  22801,
#  24649,
#  26569,
#  27889,
#  29929,
#  32041,
#  32761,
#  36481,
#  37249,
#  38809,
#  39601,
#  44521,
#  49729,
#  51529,
#  52441,
#  54289,
#  57121,
#  58081,
#  63001,
#  66049,
#  69169,
#  72361,
#  73441,
#  76729,
#  78961,
#  80089,
#  85849,
#  94249,
#  96721,
#  97969,
#  100489,
#  109561,
#  113569,
#  120409,
#  121801,
#  124609,
#  128881,
#  134689,
#  139129,
#  143641,
#  146689,
#  151321,
#  157609,
#  160801,
#  167281,
#  175561,
#  177241,
#  185761,
#  187489,
#  192721,
#  196249,
#  201601,
#  208849,
#  212521,
#  214369,
#  218089,
#  229441,
#  237169,
#  241081,
#  249001,
#  253009,
#  259081,
#  271441,
#  273529,
#  292681,
#  299209,
# ...
